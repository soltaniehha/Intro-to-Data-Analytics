# %% [markdown]
# # Exercise - A Preview of Data Science Tools
# You are a new student at Boston University and are trying to find the approximate travel times from Questrom to various locations in Boston.
#
# In the following cell, a list of distances (in miles) is given:

# %%
dist_miles_Q = [2.5, 10.3, 5.7, 8.9, 15.4, 3.6, 9.2, 4.4, 12.1, 7.5, 6.3, 11.0]  # Distances from Questrom (Q)

# %% [markdown]
# Import the numpy package as np

# %%
# Your answer goes here

# %% [markdown]
# Create a numpy array, `np_dist_miles_Q` from `dist_miles_Q`.
#
# **Hint:** one can make a numpy array from a python list, L, by `np.array(L)`.

# %%
# Your answer goes here

# %% [markdown]
# Checkout the type of both `dist_miles_Q` and `np_dist_miles_Q`:

# %%
# Your answer goes here
# Out:
# list

# %%
# Your answer goes here
# Out:
# numpy.ndarray

# %% [markdown]
# Convert the distance from miles to kilometres, save the new array as `np_dist_km_Q` and print it.
#
# **Hint:** Use the conversion formula $kilometres = miles * 1.6$

# %%
# Your answer goes here
# Out:
# [ 4.   16.48  9.12 14.24 24.64  5.76 14.72  7.04 19.36 12.   10.08 17.6 ]

# %% [markdown]
# Generate a new array `np_travel_time_hrs_Q` from `np_dist_km_Q` if you are moving at a speed of $30 \ km/h$ and print it.
#
# **Hint:** Use the formula $Time = Distance / Speed$

# %%
# Given value
speed_km_h = 30  # km/h

# %%
# Your answer goes here
# Out:
# [0.13333333 0.54933333 0.304      0.47466667 0.82133333 0.192
#  0.49066667 0.23466667 0.64533333 0.4        0.336      0.58666667]

# %% [markdown]
# Convert `np_travel_time_hrs_Q` to minutes and call it `np_travel_time_mins_Q`, then print it.

# %%
# Your answer goes here
# Out:
# [ 8.   32.96 18.24 28.48 49.28 11.52 29.44 14.08 38.72 24.   20.16 35.2 ]

# %% [markdown]
# Below is a list of distances (in miles) to the same locations from Agganis Arena:

# %%
dist_miles_A = [3.1, 7.8, 12.5, 6.4, 9.7, 4.9, 14.2, 8.3, 5.6, 10.0, 13.1, 11.2]  # Distances from Agganis Arena (A)

# %% [markdown]
# Follow the same procedure for above and print the distance in kilometres, travel time in hours and minutes as `np_dist_km_A`, `np_travel_time_hrs_A` and `np_travel_time_mins_A`.
#
# This time, use two functions to convert miles to kilometers (`convert_miles_to_km`) and calculating travel times (`calculate_travel_time`).

# %%
# Your answer goes here
# Out:
# Distance from Agganis in km: [ 4.96 12.48 20.   10.24 15.52  7.84 22.72 13.28  8.96 16.   20.96 17.92]
# Travel time from Agganis in hours: [0.16533333 0.416      0.66666667 0.34133333 0.51733333 0.26133333
#  0.75733333 0.44266667 0.29866667 0.53333333 0.69866667 0.59733333]
# Travel time from Agganis in minutes: [ 9.92 24.96 40.   20.48 31.04 15.68 45.44 26.56 17.92 32.   41.92 35.84]

# %% [markdown]
# Use the two travel times in minutes: `np_travel_time_mins_Q` and `np_travel_time_mins_A` to create a simple scatter plot.
#
# **Hint:** to do this you have several options, here are two of them: 1) use `plt.plot(x, y, 'o')`. The option 'o' here creates a scatter plot with circles; check out help `plt.plot?` to find out about other symbols. 2) use `plt.scatter(x, y)` function.

# %%
# Your answer goes here

# %% [markdown]
# Now try to use the second option. But this time also use `plt.xlabel("X-label")` & ``plt.ylabel("Y-label")`` to give the axis appropriate names:

# %%
# Your answer goes here

# %% [markdown]
# Add a $y=x$ line to the chart above. What does this mean?

# %%
# Your answer goes here

# %% [markdown]
# Create a Pandas dataframe from `np_dist_miles_Q`, `np_travel_time_mins_Q`, `np_dist_miles_A`, `np_travel_time_mins_A` with the column names `QST_dist`, `QST_time`, `AA_dist`, `AA_time`. Call this dataframe `travel`:

# %%
# Your answer goes here
# Out:
#     QST_dist  QST_time  AA_dist  AA_time
# 0        2.5      8.00      3.1     9.92
# 1       10.3     32.96      7.8    24.96
# 2        5.7     18.24     12.5    40.00
# 3        8.9     28.48      6.4    20.48
# 4       15.4     49.28      9.7    31.04
# 5        3.6     11.52      4.9    15.68
# 6        9.2     29.44     14.2    45.44
# 7        4.4     14.08      8.3    26.56
# 8       12.1     38.72      5.6    17.92
# 9        7.5     24.00     10.0    32.00
# 10       6.3     20.16     13.1    41.92
# 11      11.0     35.20     11.2    35.84

# %% [markdown]
# See if you can reproduce the above plot (without the line) by using the DataFrame method `.plot.scatter()` on `travel` DataFrame:

# %%
# Your answer goes here

# %% [markdown]
# Now with ggplot style:

# %%
# Your answer goes here

# %% [markdown]
# One advantage of using pandas for plotting is that the x and y axes are automatically labeled with the column names from the DataFrame, saving time and effort. While you still have the flexibility to rename the axis labels if needed, this feature provides a convenient and efficient way to create quick and informative plots.
