# %% [markdown]
# # Exercise - Visualizations using Seaborn

# %% [markdown]
# Now it's your turn to practice what we learned in the previous notebook.
#
# We will be using the same dataset as the previous exercise.
#
# Make sure to use the url given in the code below.

# %% [markdown]
# ## Updated Dataset Overview
# The following table explains the features in the clean dataset:
#
# **Dataset Overview**
#
# The following table explains each feature in the original dataset.
#
# |Index| Feature           | Description | Unit |
# |:----------------| :---------------- | :--------| :----: |
# |1| Date              |  date    | / |
# |2| product_id              |  Product ID (ranging from 1 to 7)    | / |
# |3| daily_unit_sales |  Daily sales - the amount of products, measured in units, that during that specific day were sold   | units |
# |4| previous_year_daily_unit_sales |  Previous Year's sales - the amount of products, measured in units, that during that specific day were sold, the previous year  | units |
# |5| daily_unit_sales_kg |  The amount of products, measured in kilograms, that during that specific day were sold  | kg |
# |6| previous_year_daily_unit_sales_kg | Previous Year's sales - the amount of products, measured in kilograms, that during that specific day were sold, the previous year | kg |
# |7|  daily_unit_returns_kg | The percentage of the products (in kg) that were shipped to selling points and were returned | %|
# |8| previous_year_daily_unit_returns_kg | The percentage of the products (in kg) that were shipped to selling points and were returned the previous year | % |
# |9| points_of_distribution | The amount of sales representatives through which the product was sold to the market that day | / |
#
# ---
#
# There are still NA values in columns: 'previous_year_daily_unit_sales', 'previous_year_daily_unit_sales_kg', 'previous_year_daily_unit_returns_kg', and this is because we don't have the data of Year 2019.

# %%
# Import libraries
from IPython.display import Pretty as disp
hint = 'https://raw.githubusercontent.com/soltaniehha/Intro-to-Data-Analytics/master/docs/hints/'  # path to hints on GitHub

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/soltaniehha/Intro-to-Data-Analytics/main/data/MEVGAL-Dairy-Sales/products-2020-2022.csv')
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#            Date  product_id  daily_unit_sales  previous_year_daily_unit_sales  \
# 0    2020-01-01           1              55.0                             NaN
# 1    2020-01-01           5               0.0                             NaN
# 2    2020-01-01           3              55.0                             NaN
# 3    2020-01-01           6              69.0                             NaN
# 4    2020-01-01           2               7.0                             NaN
# ...         ...         ...               ...                             ...
# 7667 2022-12-31           3             101.0                      259.000000
# 7668 2022-12-31           5               0.0                      193.000000
# 7669 2022-12-31           2             284.0                      480.000000
# 7670 2022-12-31           4             331.0                      331.000000
# 7671 2022-12-31           7            1620.0                     1423.766667
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7672 entries, 0 to 7671
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 7672 non-null   datetime64[ns]
#  1   product_id                           7672 non-null   int64
#  2   daily_unit_sales                     7672 non-null   float64
#  3   previous_year_daily_unit_sales       5110 non-null   float64
#  4   daily_unit_sales_kg                  7672 non-null   float64
#  5   previous_year_daily_unit_sales_kg    5110 non-null   float64
#  6   daily_unit_returns_kg                7672 non-null   object
#  7   previous_year_daily_unit_returns_kg  5110 non-null   object
#  8   points_of_distribution               7672 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(2)
# memory usage: 539.6+ KB

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Product popularity
#
# Create a bar chart that displays the average `daily_unit_sales_kg` for each product.
#
# Hint: check the help function for `barplot()` to see what aggregate functions are supported and what is the default value.

# %%
# Your code goes here
#disp(hint + 'Mevgal-01')

# %% [markdown]
# Now that we have the basic barplot, we will make the following changes:
#
# *   Set the style to: `ggplot`
# *   Add a title: `Average Daily Unit Sales in Kg`
# *   Change the y-axis label to: `Average Daily Unit Sales (Kg)`
# *   Change the x-axis label to: `Product ID`
#
# Hint: Remember that you have to plot the barplot again and make the changes.

# %%
# Your code goes here
#disp(hint + 'Mevgal-02')

# %% [markdown]
# ### Distribution - Histogram
#
# Let's find out the distribution of daily unit sales (`daily_unit_sales`) for the most popular product, i.e. Product 1. This will help us underdtand what the most typical demand for this product looks like.
#
# Make sure to add the Title and check for the x-axis label.
#
# Hint: Use a histogram for this plot.

# %%
# Your code goes here
#disp(hint + 'Mevgal-03')

# %% [markdown]
# Now repeat this with `kde=True` in the arguments to get a continuous line (kernel density estimator) to show the distribution as a probablity function.

# %%
# Your code goes here
#disp(hint + 'Mevgal-04')

# %% [markdown]
# Now, let's look at all the product sales distributions (without the kde):

# %%
# Your code goes here
#disp(hint + 'Mevgal-05')

# %% [markdown]
# ### Distribution - Box plot
#
# We want to check if there is any difference in the `daily_unit_sales` and `daily_unit_sales_kg` for Product 6. Create a boxplot for both of these columns for all three years side-by-side and compare the results.
#
# Hint: You can create a new smaller dataframe by filtering out columns for just Product 6.
#
# Hint: You might have to create a "Year" column.
#
# Hint: Remember subplots from your Bootcamp. You can define subplots by using:
#
# *fig, axes = plt.subplots(1,2, figsize=(12,6))*

# %%
# Your code goes here
#disp(hint + 'Mevgal-06')

# %% [markdown]
# Before we go into the analysis of these plots, let's make sure the axes are labelled right and that our plots have a proper title.
#
# Add the following to the above chart:
#
# *   Set the titles for both the graphs as `Daily Sales - Product 6` and `Daily Sales (kg) - Product 6` respectively
# *   Set the y-axis labels as `Daily Sales (units)` and `Daily Sales (kg)` respectively
# *   Add a title for both charts - `Daily Sales Comparison - Product 6`
# *   Look through the different `color_palette` options offered by Seaborn and add a little colour to your graph to differentiate various years
#
# Hint: `suptitle` function is used to define a common title for all subplots.

# %%
# Your code goes here
#disp(hint + 'Mevgal-07')

# %% [markdown]
# We see that there are some differences in the `daily_unit_sales` and `daily_unit_sales_kg` numbers for 2021. In order to investigate further, we can create the `package_size` column to investigate if the packaging was changed in 2021.
#
# The package size per unit can be derived from the division of *'daily_unit_sales_kg'* and *'daily_unit_sales'* as shown below:
#
# \begin{align}
#         \texttt{package_size} = \frac{\texttt{daily_unit_sales_kg}}{\texttt{daily_unit_sales}}
#     \end{align}
#
# \
#
# Create a new `package_size` column before moving to the next step:

# %%
# Your code goes here
#disp(hint + 'Mevgal-08')

# %% [markdown]
# Make a boxplot to check the `package_size` of Product 6 over the three years.
#
# Hint: You can use the smaller dataframe you created earlier only for Product 6 even here.

# %%
# Your code goes here
#disp(hint + 'Mevgal-09')

# %% [markdown]
# This change explains why we saw some inconsistencies in the sales units vs. kilograms.

# %% [markdown]
# ### Timeseries plots
#
# Let's look at the daily pattern over time using a lineplot for each product:

# %%
# Your code goes here
#disp(hint + 'Mevgal-10')

# %% [markdown]
# This is way too busy and we cannot understand any patterns. Let's aggregate to the month level and then try again.
#
# First, create a Month column than includes both month and year:
#
# Hint: Use `.dt.to_period('M')` to create monthly frequency. Then use `.dt.to_timestamp()` to convert this monthly object into a date object, otherwise, you will not be able to utilize some of the seaborn/matplotlib automatic date handling.

# %%
# Your code goes here
#disp(hint + 'Mevgal-11')
# Out:
#        Month
# 0 2020-01-01
# 1 2020-01-01

# %% [markdown]
# Then, for each product, aggregate the data to month level (year-month-product level), using `groupby()`. Use `sum()` as the aggregate function. Call the resulting DataFrame `monthly_aggregated_df`.
#
# Discussion: what are the downsides and upsides of `sum()` in this scenario?

# %%
# Your code goes here
#disp(hint + 'Mevgal-12')
# Out:
#        Month  product_id  daily_unit_sales_kg
# 0 2020-01-01           1              50928.6
# 1 2020-01-01           2              19697.0
# 2 2020-01-01           3              13296.6

# %%
# Your code goes here
#disp(hint + 'Mevgal-13')
