# %% [markdown]
# **Objective:** Familiarize yourself with Seaborn and Pandas by visualizing data from an open data source.
#
# **Data Source:** We'll be using the [Online Retail](https://archive.ics.uci.edu/dataset/352/online+retail) dataset from the UCI Machine Learning Repository.

# %% [markdown]
# Import the necessary libraries:

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load the "Online Retail" dataset and take a quick look at the first few rows of the dataset to understand its structure:

# %%
# Your answer goes here

# %%
online_retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Data Cleaning
# Inspect if the variables are loaded in the intended data type:

# %%
online_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# Do you need to convert any of the types?
#
# For instance, it might be a good idea to convert CustomerID to Int64?

# %%
# Your answer goes here
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
online_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  int64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 33.1+ MB

# %%
online_retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Can you spot some bad values that need to be modified/deleted?

# %%
# Anything missing in Quantity?
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# Are there zero values in Quantity?
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# Are there negative values in Quantity?
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Let's store the returns into another DataFrame:

# %%
# store the returns into a new DataFrame
returns =

# store the rest in a new DataFrame keeping the original DF untouched
sales =

# %% [markdown]
# How much was the company's gross sales?
#
# This is the total sales amount before any deductions. It represents the company's total revenue from sales transactions without accounting for returns, allowances, or discounts.

# %%
# Out:
# 10644560.0

# %% [markdown]
# About the return?

# %%
# Out:
# -896812.0

# %% [markdown]
# What's the new sales?
#
# This is the amount after deducting returns, allowances, and discounts from the gross sales. It provides a clearer picture of a company's actual revenue from sales transactions.
#
# `Net_Sales = Gross_Sales − (Returns + Allowances + Discounts)`

# %%
# Out:
# 9747748.0

# %% [markdown]
# Any bad values in UnitPrice?

# %%
# Out:
# -11062.06

# %%
# Any negative UnitPrice?
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06       99999  United Kingdom
# 299984  -11062.06       99999  United Kingdom

# %%
sales[sales.UnitPrice == 11062.06]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06       99999  United Kingdom

# %% [markdown]
# Remove the UnitPrice values equal to 11062.06 or -11062.06:

# %%
sales =

# %%
sales.UnitPrice.max()
# Out:
# 13541.33

# %%
# Any zero values for UnitPrice?
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 535334    581211     22142                         check        14
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 622    2010-12-01 11:52:00        0.0       99999  United Kingdom
# ...

# %%
# Removing UnitPrice = 0
sales =

# %% [markdown]
# Sort the data based on Quantity and inspect any strange behavior:

# %%
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 127654    547243     21876                      POTTERING MUG         1
# 113358    545978    47590A        BLUE HAPPY BIRTHDAY BUNTING         1
# 113359    545978    47590B        PINK HAPPY BIRTHDAY BUNTING         1
# 207501    554992     84828  JUNGLE POPSICLES ICE LOLLY MOULDS         1
# 113362    545978     22192              BLUE DINER WALL CLOCK         1
# ...          ...       ...                                ...       ...
# 97432     544612     22053              EMPIRE DESIGN ROSETTE      3906
# 206121    554868     22197               SMALL POPCORN HOLDER      4300
# 421632    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 61619     541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540421    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Let's create a new DF for Wholesaling. We define the arbitrary number of more than 100 for being a bulk purchase:

# %%
sales_ws =
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 96        536378     21212    PACK OF 72 RETROSPOT CAKE CASES       120
# 178       536387     79321                      CHILLI LIGHTS       192
# 179       536387     22780     LIGHT GARLAND BUTTERFILES PINK       192
# 180       536387     22779         WOODEN OWLS LIGHT GARLAND        192
# 181       536387     22466      FAIRY TALE COTTAGE NIGHTLIGHT       432
# ...          ...       ...                                ...       ...
# 540442    581487     21137           BLACK RECORD COVER FRAME       120
# 541286    581497     22355          CHARLOTTE BAG SUKI DESIGN       110
# 541545    581501     22319  HAIRCLIPS FORTIES FABRIC ASSORTED       180
# 541702    581566     23404         HOME SWEET HOME BLACKBOARD       144
# 541711    581567     21326   AGED GLASS SILVER T-LIGHT HOLDER       144
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Let's create a new DF for the "small" sales:

# %%
sales_ss =
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Find the top 10 countries by number of transactions:

# %%
country_counts =
# Out:
# United Kingdom    485122
# Germany             9040
# France              8407
# EIRE                7890
# Spain               2484
# Netherlands         2359
# Belgium             2031
# Switzerland         1966
# Portugal            1501
# Australia           1182
# Name: Country, dtype: int64

# %% [markdown]
# # Visualization
# Create a bar plot to visualize the results above:

# %%
# Your answer goes here

# %%
# Alternatively

# %% [markdown]
# Plot the number of transactions per month:

# %%
# Your answer goes here
monthly_transactions
# Out:
#     Month  Transactions
# 0       1         34306
# 1       2         27105
# 2       3         35803
# 3       4         29096
# 4       5         36164
# 5       6         35977
# 6       7         38645
# 7       8         34482
# 8       9         49261
# 9      10         59304
# 10     11         83369
# 11     12         66591

# %%
# Your answer goes here

# %% [markdown]
# Do the same for the revenue generated by small and whole sales:

# %%
# Your answer goes here
monthly_rev_ss
# Out:
# InvoiceDate
# 1      515270.020
# 2      453424.230
# 3      605852.050
# 4      462598.371
# 5      664608.670
# 6      627602.650
# 7      600464.621
# 8      608201.330
# 9      864973.102
# 10     939722.730
# 11    1270429.760
# 12    1098789.220
# dtype: float64

# %%
monthly_rev_ss.sum()
# Out:
# 8711936.753999999

# %%
# Your answer goes here

# %%
# Your answer goes here
monthly_rev_ws
# Out:
# InvoiceDate
# 1     176094.54
# 2      70207.66
# 3     111787.31
# 4      75210.25
# 5     105927.35
# 6     134137.25
# 7     118756.57
# 8     139874.99
# 9     193617.07
# 10    215256.57
# 11    239066.57
# 12    363749.60
# dtype: float64

# %%
monthly_rev_ws.sum()
# Out:
# 1943685.7300000002

# %%
# Your answer goes here

# %% [markdown]
# Visualize the distribution of Quantity:

# %%
# Your answer goes here

# %%
sales_ws.sort_values('Quantity').tail(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 4945      536830     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 433788    573995     16014          SMALL CHINESE STYLE SCISSOR      3000
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 4945   2010-12-02 17:38:00       0.18       16754  United Kingdom
# ...

# %% [markdown]
# Redo the histogram excluding outliers:

# %%
# Your answer goes here

# %%
# Your answer goes here

# %% [markdown]
# # More Advanced Viz
# Create a timeseries of number of transactions per day:

# %%
# Your answer goes here

# %%
# Your answer goes here
sales_ss

# %%
# Your answer goes here
sales_ws

# %% [markdown]
# Create a scatter plot to visualize the relationship between Quantity and UnitPrice for 1000 sample transactions:

# %%
# Your answer goes here

# %% [markdown]
# Create a box plot to visualize the distribution of quantities for the top 5 most sold items:

# %%
# Your answer goes here

# %% [markdown]
# Create a pair plot for a sample of 500 transactions to visualize relationships between Quantity, UnitPrice, and Revenue (calculated as Quantity * UnitPrice):

# %%
# Your answer goes here
# Out:
# <ipython-input-50-b8ce9483c678>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_ss['Revenue'] = sales_ss['Quantity'] * sales_ss['UnitPrice']

# %% [markdown]
# Reflect on the visualizations you've created. What insights can you draw from the "Online Retail" dataset based on your plots?
# Experiment with other Seaborn plots and customize the appearance of your visualizations and further explore this dataset.
